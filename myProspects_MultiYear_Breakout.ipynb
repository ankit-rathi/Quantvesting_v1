# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Tradevesting_v1/blob/main/myProspects_MultiYear_Breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#from google.colab import drive
#drive.mount('/content/drive')

#mypf = pd.read_csv('/content/drive/My Drive/data/stocks/myProspectsScrips.csv')

path_mypf = 'https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/'

mypf = pd.read_csv(path_mypf + 'myProspectsScrips.csv')

#mypf = mypf[(mypf['Criteria'] == 'V40') | (mypf['Criteria'] == 'V40N')]
#mypf = mypf[~mypf['Criteria'].isin(['V40','V40N'])]
mypf = mypf[mypf['TFrame'] == 'W']

stock_n100 = mypf['Symbol'].unique()

exclude = ['CADILAHC','MMTC','JIOFIN','SCHAEFFLER ','ADANITRANS', 'EQUITAS', 'MCDOWELL-N']

stocks = mypf[~mypf['Symbol'].isin(exclude) ]['Symbol'].unique()

#stocks = ['ERIS']

# %%
import yfinance as yf
import pandas as pd

def detect_multiyear_breakout(stocks, years=3):
    breakout_results = []

    for ticker in stocks:
        # Fetch historical stock data with monthly intervals
        stock_data = yf.download(ticker + '.NS', period='max', interval='1mo')

        # Calculate the rolling maximum over the specified number of years (in months)
        rolling_max = stock_data['High'].rolling(window=years*12).max()

        # Detect breakouts: when the current month's high is greater than the rolling max
        stock_data['Multiyear Breakout'] = stock_data['High'] > rolling_max.shift(1)

        # Initialize variable to track the last breakout date and price
        last_breakout_date = None
        last_breakout_high = None

        # Filter rows where a breakout occurs
        for date, row in stock_data.iterrows():
            if row['Multiyear Breakout']:
                # Ensure 12 months have passed since the last breakout
                if last_breakout_date is None or (date - last_breakout_date).days >= 200:
                    # Register this as a breakout
                    breakout_results.append({
                        'Stock': ticker,
                        'Month': date.strftime('%Y-%m'),
                        'Breakout Level Close Price': row['Close']
                    })
                    # Update the last breakout date and price
                    last_breakout_date = date
                    last_breakout_high = row['High']

    # Convert the results into a DataFrame
    breakout_df = pd.DataFrame(breakout_results)
    return breakout_df

breakout_df = detect_multiyear_breakout(stocks, years=3)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
breakout_df.sort_values(by = 'Month', ascending=True).tail(10)
# Out:
#           Stock    Month  Breakout Level Close Price
# 61   AVANTIFEED  2024-07                  680.650024
# 54     ASTRAZEN  2024-07                 7036.450195
# 239   FOSECOIND  2024-07                 4756.700195
# 130        CAMS  2024-07                 4534.200195
# 407        ONGC  2024-07                  334.200012
# 194       DIXON  2024-07                12106.450195
# 335   LICHSGFIN  2024-07                  767.250000
# 250        HSCL  2024-07                  429.200012
# 134  CAPLIPOINT  2024-08                 1585.500000
# 166        CERA  2024-08                10101.500000
